# %%
import numpy as np
import os
import scipy.sparse as sparse
from scipy.stats import bernoulli, poisson
import analysis_utils_mine as utils

import plotly.graph_objects as go
import chart_studio
import json
import pandas as pd
import ast
from datetime import datetime
import torch
import pickle

# %%
source_dir = os.path.join("../data/tweets_cong_115_116/")

# Load TBIP data.
data_dir = os.path.join(source_dir, "clean2")
(counts, vocabulary, author_indices, 
 author_map) = utils.load_text_data(data_dir)

# Load TBIP parameters.
param_dir = os.path.join(source_dir, "tbip-og-k50-expanded-vocab-with-mallet-scaled-topics/params/")
(document_loc, document_scale, objective_topic_loc, objective_topic_scale, 
 ideological_topic_loc, ideological_topic_scale, ideal_point_loc, 
 ideal_point_scale) = utils.load_tbip_parameters(param_dir)

# Compute means from variational parameters
document_mean = np.exp(document_loc + document_scale ** 2 / 2)
objective_topic_mean = np.exp(objective_topic_loc + 
                              objective_topic_scale ** 2 / 2)
ideological_topic_mean = ideological_topic_loc
ideal_point_mean = ideal_point_loc

# %%
print(document_mean.shape)
print(objective_topic_mean.shape)
print(ideological_topic_mean.shape)
print(ideal_point_mean.shape)
ideal_point_mean = -1*ideal_point_mean
ideological_topic_loc = ideological_topic_loc * -1
# Out:
# (295327, 50)
# (50, 9343)
# (50, 9343)
# (471,)

# %%
utils.print_topics(objective_topic_loc, 
                   objective_topic_scale, 
                   ideological_topic_loc, 
                   ideological_topic_scale, 
                   vocabulary, 
                   20)
# Out:
# ['Ideal Point = -1.0, Topic = 0: history, american, african, first, african american, woman, asian, friend, man, elected, african americans, american woman, advocate, true, museum, congresswoman, dear, sad, passing, native'
#  'Ideal Point = -0.5, Topic = 0: history, american, first, african, friend, woman, true, african american, man, passing, advocate, colleague, rest, dedicated, native, former, sad, asian, elected, missed'
#  'Ideal Point = 0.0, Topic = 0: friend, american, history, true, passing, first, man, former, colleague, woman, rest, dedicated, missed, hero, native, advocate, bush, african, sad, hear'
#  'Ideal Point = 0.5, Topic = 0: friend, passing, former, true, missed, american, bush, hero, dedicated, colleague, rest, man, native, first, hear, history, advocate, sad, woman, patriot'
#  'Ideal Point = 1.0, Topic = 0: friend, bush, passing, former, hero, missed, true, dedicated, rest, colleague, hear, man, fellow, native, american, away, texan, american hero, patriot, good friend'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 1: bank, honored, congrats, congratulations, proud, score, represent, scorecard, champion, ex, im, award, writing, ex im, im bank, ex im bank, receive, girl, receiving, perfect'
#  'Ideal Point = -0.5, Topic = 1: honored, congrats, congratulations, proud, award, represent, receive, bank, champion, receiving, named, community, winning, gold, recognized, ceremony, ex, recognition, incredibly, recognizing'
#  'Ideal Point = 0.0, Topic = 1: honored, congratulations, congrats, award, proud, receive, represent, named, receiving, champion, winning, recognized, gold, medal, ceremony, district, community, star, outstanding, recognizing'
#  'Ideal Point = 0.5, Topic = 1: honored, congratulations, congrats, award, proud, receive, named, represent, recognized, medal, receiving, winning, district, star, outstanding, gold, ceremony, nfib, presented, best'
#  'Ideal Point = 1.0, Topic = 1: honored, nfib, congratulations, award, congrats, reptomprice, named, receive, proud, uschamber, freedomworks, enterprise, spirit, star, gen, medal, outstanding, district, first district, represent'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 2: count, important, former, important public, former educator, school funding, funding, educator, public, former teacher, education, invest, public school, full, school, students, high, high school, challenge, teacher'
#  'Ideal Point = -0.5, Topic = 2: school, students, high, important, high school, former, count, art, full, competition, challenge, funding, public school, educator, public, app, teacher, education, invest, district'
#  'Ideal Point = 0.0, Topic = 2: school, students, high, high school, art, competition, challenge, art competition, app, district, winner, teacher, student, hs, school students, elementary, teachers, submit, high school students, bright'
#  'Ideal Point = 0.5, Topic = 2: school, students, high, high school, competition, art, art competition, district, challenge, app, winner, student, teachers, science, hs, school students, elementary, bright, middle, schools'
#  'Ideal Point = 1.0, Topic = 2: school, high, students, high school, competition, art, art competition, student, science, winner, teachers, district, schools, congrats, app, hs, parents, challenge, middle, choice'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 3: msnbc, tonight, joining, allinwithchris, gregorymeeks, tune, politicsnation, show, cnn, discuss, pm, chrislhayes, joyannreid, hardball, amjoyshow, talking, et, pt, thereval, mitchellreports'
#  'Ideal Point = -0.5, Topic = 3: tonight, tune, joining, msnbc, show, discuss, talking, pm, et, cnn, listen, sotu, discussing, interview, latest, pt, pm et, hardball, est, icymi'
#  'Ideal Point = 0.0, Topic = 3: tune, tonight, joining, discuss, talking, show, listen, interview, sotu, et, pm, discussing, live, msnbc, cnn, latest, icymi, foxnews, looking, est'
#  'Ideal Point = 0.5, Topic = 3: tune, tonight, live, talking, listen, discuss, foxnews, joining, show, interview, foxbusiness, sotu, et, discussing, icymi, radio, pm, coming, listen live, looking'
#  'Ideal Point = 1.0, Topic = 3: foxbusiness, foxnews, live, tune, varneyco, listen, talking, tonight, discuss, foxandfriends, joining, interview, seanhannity, radio, listen live, show, online, central, americanewsroom, sotu'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 4: happy, celebrating, friend, everyone, wishing, force, world, ramadan, mother, birthday, holiday, celebrate, happy birthday, best, peace, season, mubarak, barackobama, hope, mom'
#  'Ideal Point = -0.5, Topic = 4: happy, celebrating, birthday, force, wishing, everyone, happy birthday, holiday, mother, celebrate, season, best, world, hope, task, family, thanksgiving, task force, mom, friend'
#  'Ideal Point = 0.0, Topic = 4: happy, birthday, force, celebrating, happy birthday, wishing, everyone, holiday, season, hope, celebrate, christmas, family, best, thanksgiving, task, mother, father, corps, task force'
#  'Ideal Point = 0.5, Topic = 4: happy, birthday, force, happy birthday, air, wishing, celebrating, christmas, everyone, blessed, season, hope, air force, independence, holiday, family, corps, thanksgiving, wonderful, father'
#  'Ideal Point = 1.0, Topic = 4: happy, air, birthday, happy birthday, christmas, force, blessed, air force, usmc, usairforce, wishing, independence, wonderful, celebrating, corps, marine, base, hope, army, marines'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 5: maria, help, fellow, resources, provide, emergency, funding, fellow americans, response, coronavirus, federal, pandemic, hurricane maria, testing, haiti, aid, still, unemployment, state, needs'
#  'Ideal Point = -0.5, Topic = 5: help, resources, provide, funding, emergency, response, coronavirus, federal, needed, relief, state, disaster, aid, pandemic, testing, assistance, ensure, local, communities, hurricane'
#  'Ideal Point = 0.0, Topic = 5: provide, help, resources, funding, coronavirus, emergency, relief, response, needed, state, disaster, federal, assistance, recovery, hurricane, aid, local, fema, pandemic, covid'
#  'Ideal Point = 0.5, Topic = 5: provide, funding, help, resources, relief, coronavirus, needed, emergency, recovery, response, disaster, state, businesses, hurricane, assistance, federal, fema, local, covid, much'
#  'Ideal Point = 1.0, Topic = 5: provide, funding, relief, recovery, resources, help, businesses, coronavirus, needed, texans, disaster, hurricane, emergency, response, fema, harvey, state, regulatory relief, provides, assistance'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 6: dreamers, workers, daca, wages, american, housedemocrats, deserve, labor, better, tps, worker, families, status, paychecks, promise, fighting, recipients, renew, country, union'
#  'Ideal Point = -0.5, Topic = 6: workers, american, dreamers, better, deserve, daca, families, wages, labor, americans, promise, hardworking, country, dream, housedemocrats, citizens, hard, recipients, tps, protect'
#  'Ideal Point = 0.0, Topic = 6: better, american, deserve, workers, americans, families, citizens, daca, dreamers, dream, hardworking, american families, country, promise, everyday, hard, labor, americans deserve, deserve better, protect'
#  'Ideal Point = 0.5, Topic = 6: housegop, better, american, deserve, americans, citizens, families, everyday, dream, retweet, american families, workers, way, hardworking, american dream, americans deserve, deserve better, country, daca, hard'
#  'Ideal Point = 1.0, Topic = 6: housegop, better, retweet, deserve, tennesseans, american, citizens, americans, everyday, miners, way, everyday americans, families, american families, dream, american dream, achieve, delivering, place, american citizens'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 7: economy, hbcu, minority, housesbcdems, latinos, diversity, diverse, businesses, cities, hbcus, growing, communities, pipeline, role, tech, workforce, latino, local, companies, hbcucaucus'
#  'Ideal Point = -0.5, Topic = 7: economy, businesses, local, role, tech, communities, development, innovation, grow, minority, growing, generation, industry, companies, workforce, cities, diverse, farmers, hbcu, technology'
#  'Ideal Point = 0.0, Topic = 7: businesses, economy, local, farmers, role, industry, development, innovation, farm, tech, technology, manufacturing, communities, grow, owners, help, generation, company, agriculture, biz'
#  'Ideal Point = 0.5, Topic = 7: farmers, businesses, local, farm, ag, industry, agriculture, america, development, economy, innovation, role, manufacturing, technology, owners, rural, state, biz, tech, employees'
#  'Ideal Point = 1.0, Topic = 7: ag, farmers, housesmallbiz, farm, agriculture, houseagnews, hoosier, america, employees, local, businesses, industry, ranchers, rural, bureau, producers, farm bureau, manufacturing, development, innovation'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 8: fair, tomorrow, help, hours, agencies, agency, federal, library, fair share, resource, workshop, constituent, saturday, tuesday, district, services, rsvp, learn, details, share'
#  'Ideal Point = -0.5, Topic = 8: tomorrow, fair, hours, help, federal, agency, agencies, resource, library, constituent, details, tuesday, stop, workshop, wednesday, thursday, district, services, mobile, assist'
#  'Ideal Point = 0.0, Topic = 8: tomorrow, fair, hours, help, federal, stop, agency, details, agencies, mobile, hosting, resource, tuesday, constituent, library, wednesday, thursday, next, assist, reminder'
#  'Ideal Point = 0.5, Topic = 8: tomorrow, hours, stop, fair, federal, help, mobile, details, hosting, agency, next, agencies, thursday, wednesday, tuesday, resource, reminder, job, constituent, assist'
#  'Ideal Point = 1.0, Topic = 8: stop, tomorrow, hours, hosting, mobile, job, details, federal, traveling, help, fair, next, bureaucracy, county, monday, cdt, counties, harrison, courthouse, host'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 9: medicaid, security, cuts, social, seniors, medicare, social security, housebudgetdems, budget, socialsecurity, protect, benefits, medicare medicaid, trump budget, programs, proposed, billion, americans, economic, vital'
#  'Ideal Point = -0.5, Topic = 9: medicaid, budget, security, social, seniors, medicare, cuts, social security, benefits, proposed, socialsecurity, protect, spending, cutting, programs, billion, housebudgetdems, retirement, media, expansion'
#  'Ideal Point = 0.0, Topic = 9: budget, seniors, social, medicare, spending, security, social security, medicaid, cuts, cutting, proposed, cut, retirement, benefits, billion, fiscal, debt, media, proposal, expansion'
#  'Ideal Point = 0.5, Topic = 9: budget, spending, debt, medicare, seniors, social, cut, cutting, fiscal, trillion, ly, security, social security, republicanstudy, retirement, proposed, proposal, deficit, plan, housebudgetgop'
#  'Ideal Point = 1.0, Topic = 9: debt, spending, republicanstudy, budget, ly, housebudgetgop, stimulus, trillion, mp, ceiling, debt ceiling, control, fiscal, cut, plan, limit, responsible, cut spending, gov, balances'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 10: openletterbot, trump, immigrants, immigrant, hispaniccaucus, cruel, families, admin, trump administration, policies, children, border, trump admin, immigration, administration, policy, separated, realdonaldtrump, detention, family'
#  'Ideal Point = -0.5, Topic = 10: trump, children, administration, families, trump administration, policy, immigrants, admin, immigrant, hispaniccaucus, policies, cruel, trump admin, immigration, parents, border, detention, child, realdonaldtrump, separated'
#  'Ideal Point = 0.0, Topic = 10: children, administration, trump, policy, families, trump administration, parents, admin, policies, immigrants, ice, child, seeking, trump admin, immigrant, immigration, hispaniccaucus, citizenship, country, old'
#  'Ideal Point = 0.5, Topic = 10: administration, children, policy, trump, parents, trump administration, yr, families, ice, seeking, old, country, child, citizenship, parent, admin, apart, policies, cream, grandchildren'
#  'Ideal Point = 1.0, Topic = 10: administration, children, yr, policy, parents, ice, old, seeking, cream, yr old, parent, grandchildren, trump, trump administration, week, families, country, breaking, yesterday, current'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 11: muslim, decision, court, scotus, kavanaugh, muslim ban, ban, applaud, supreme, supreme court, silence, complicity, judge, ford, blasey, blasey ford, discriminatory, overturn, potus, nominee'
#  'Ideal Point = -0.5, Topic = 11: decision, court, scotus, ban, supreme, supreme court, kavanaugh, judge, applaud, executive, potus, muslim, ford, ruling, constitutional, nominee, unconstitutional, confirmed, disappointed, confirmation'
#  'Ideal Point = 0.0, Topic = 11: court, decision, scotus, executive, supreme, supreme court, judge, ban, potus, kavanaugh, constitutional, ruling, justice, constitution, branch, confirmed, unconstitutional, confirmation, applaud, nominee'
#  'Ideal Point = 0.5, Topic = 11: constitution, court, executive, decision, justice, scotus, supreme, judge, supreme court, potus, overreach, constitutional, ban, branch, ruling, authority, amnesty, confirmed, confirmation, kavanaugh'
#  'Ideal Point = 1.0, Topic = 11: constitution, overreach, amnesty, executive, justice, court, sentedcruz, decision, neil, powers, johncornyn, separation, branch, gorsuch, potus, judge, constitutional, supreme, authority, supreme court'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 12: justice, fight, let, together, voices, diversity, moral, values, america, heard, courage, theblackcaucus, solidarity, voice, moment, kamalaharris, nation, progress, injustice, powerful'
#  'Ideal Point = -0.5, Topic = 12: justice, together, let, fight, heard, america, story, voice, values, life, nation, voices, country, celebrate, legacy, words, world, commitment, powerful, stories'
#  'Ideal Point = 0.0, Topic = 12: life, story, together, heard, america, celebrate, voice, nation, let, legacy, world, country, values, freedom, words, stories, fight, commitment, faith, sharing'
#  'Ideal Point = 0.5, Topic = 12: life, story, freedom, history, celebrate, conservative, god, heard, together, voice, america, nation, faith, liberty, world, reagan, legacy, country, stories, martin'
#  'Ideal Point = 1.0, Topic = 12: lord, god, conservative, life, psalm, pro, history, freedom, pro life, reagan, christ, story, jesus, son, unborn, liberty, lincoln, celebrate, ronald reagan, ronald'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 13: nyc, students, housing, food, nyers, teachers, education, affordable, schools, kids, youth, hungry, snap, poverty, betsydevosed, college, program, programs, hunger, edlaborcmte'
#  'Ideal Point = -0.5, Topic = 13: students, education, food, program, housing, nyc, kids, schools, programs, college, teachers, youth, help, poverty, grant, snap, affordable, opportunities, families, grants'
#  'Ideal Point = 0.0, Topic = 13: program, education, students, food, programs, kids, college, schools, housing, help, grant, training, opportunities, youth, learning, poverty, career, stem, community, grants'
#  'Ideal Point = 0.5, Topic = 13: program, education, programs, kids, college, food, workforce, help, training, students, schools, opportunities, grant, career, learning, skills, edworkforce, community, housing, stem'
#  'Ideal Point = 1.0, Topic = 13: edworkforce, program, workforce, education, bank, programs, training, welfare, cte, help, opportunities, college, career, kids, skills, grant, technical, schools, learning, food'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 14: veterans, military, vetaffairsdems, confederate, veteran, vets, post, servicemembers, benefits, active, duty, japanese, deported, served, flag, exposed, vietnam, earned, help, country'
#  'Ideal Point = -0.5, Topic = 14: veterans, military, veteran, vets, post, benefits, flag, vetaffairsdems, vietnam, servicemembers, active, home, help, families, served, earned, duty, members, wwii, country'
#  'Ideal Point = 0.0, Topic = 14: veterans, military, veteran, vets, post, home, vietnam, flag, benefits, wwii, war, navy, help, army, members, nation, active, families, servicemembers, earned'
#  'Ideal Point = 0.5, Topic = 14: veterans, military, veteran, vets, post, war, home, housevetaffairs, wwii, army, vietnam, navy, flag, memorial, return, nation, benefits, flight, members, help'
#  'Ideal Point = 1.0, Topic = 14: veterans, housevetaffairs, military, war, flight, vets, veteran, memorial, return, post, wwii, army, deserve, home, navy, nation, vietnam, flag, world, deptvetaffairs'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 15: video, check, follow, nytimes, pro, via, next, facebook, photo, slate, cover, page, piece, thehill, congresswoman, op, twitter, latimes, week, next week'
#  'Ideal Point = -0.5, Topic = 15: check, via, video, follow, facebook, next, week, op, photo, nytimes, page, thehill, pro, updates, next week, twitter, article, latest, piece, photos'
#  'Ideal Point = 0.0, Topic = 15: via, check, week, follow, op, facebook, next, latest, photo, video, page, updates, thehill, icymi, article, next week, newsletter, photos, twitter, fb'
#  'Ideal Point = 0.5, Topic = 15: via, week, check, gop, op, latest, sign, newsletter, icymi, follow, facebook, weekly, next, fb, wsj, updates, article, photo, page, thehill'
#  'Ideal Point = 1.0, Topic = 15: gop, via, wsj, week, sign, weekly, dcexaminer, check, newsletter, icymi, latest, op, weekly newsletter, column, gopwhip, fb, ly, washtimes, schedule, facebook'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 16: bronx, community, street, center, amazing, wonderful, park, event, annual, weekend, welcome, rally, st, celebration, celebrate, dominican, senior, part, capitol, mayor'
#  'Ideal Point = -0.5, Topic = 16: community, center, event, welcome, bronx, weekend, annual, capitol, wonderful, park, st, opening, amazing, mayor, beautiful, tour, celebration, senior, part, visiting'
#  'Ideal Point = 0.0, Topic = 16: center, event, community, capitol, welcome, weekend, annual, tour, visiting, opening, enjoyed, st, mayor, beautiful, wonderful, seeing, stopped, park, facility, night'
#  'Ideal Point = 0.5, Topic = 16: tour, enjoyed, capitol, center, visiting, event, speaking, welcome, weekend, visit, annual, afternoon, community, opening, county, stopped, yesterday, facility, st, chamber'
#  'Ideal Point = 1.0, Topic = 16: speaking, visit, enjoyed, tour, county, visiting, capitol, afternoon, springs, center, coffee, event, chamber, welcome, yesterday, cincinnati, folks, johnboozman, enjoyed visiting, weekend'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 17: lives, never, lost, remember, country, forget, stop, fought, women, serve, grateful, holocaust, indigenous, let, serving, men, fight, nation, stop fighting, armenian'
#  'Ideal Point = -0.5, Topic = 17: lives, never, remember, lost, country, women, serve, forget, men, grateful, nation, serving, brave, fought, served, sacrifice, let, gave, heroes, holocaust'
#  'Ideal Point = 0.0, Topic = 17: lives, women, never, remember, country, nation, men, lost, grateful, serve, forget, brave, serving, sacrifice, heroes, served, gave, fought, freedom, protect'
#  'Ideal Point = 0.5, Topic = 17: women, nation, lives, men, remember, country, never, grateful, serve, brave, heroes, sacrifice, lost, serving, served, forget, freedom, protect, forces, anniversary'
#  'Ideal Point = 1.0, Topic = 17: women, nation, men, heroes, lives, grateful, country, remember, serve, brave, sacrifice, moment, never, protect, greatest, freedom, served, serving, brave men, freedoms'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 18: good, news, big, team, win, watching, let, uswnt, game, hand, royals, first, dodgers, luck, bad, warriors, world, cwsoftballgame, best, space'
#  'Ideal Point = -0.5, Topic = 18: good, news, big, team, win, game, first, watching, luck, hand, space, usa, best, good luck, good news, nasa, let, world, series, bad'
#  'Ideal Point = 0.0, Topic = 18: good, news, big, team, win, game, first, luck, space, usa, good news, hand, nasa, good luck, best, state, watching, series, exciting, baseball'
#  'Ideal Point = 0.5, Topic = 18: good, news, team, big, win, game, state, space, good news, usa, luck, first, nasa, good luck, hand, best, baseball, football, championship, breaking'
#  'Ideal Point = 1.0, Topic = 18: good, news, team, big, state, win, game, good news, space, usa, luck, first, congrats, nasa, breaking, football, championship, good luck, baseball, tonight'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 19: act, housedemocrats, proud, bipartisan, pass, legislation, senkamalaharris, corybooker, introduced, sensanders, passed, finally, senatormenendez, cosponsor, chrismurphyct, introducing, proud original cosponsor, proud original, introduce, housedemocrats passed'
#  'Ideal Point = -0.5, Topic = 19: act, bipartisan, proud, legislation, passed, pass, introduced, housedemocrats, cosponsor, introduce, help, protect, voted, introducing, ensure, hr, passage, intro, week, original'
#  'Ideal Point = 0.0, Topic = 19: act, bipartisan, passed, legislation, proud, introduced, pass, protect, voted, help, hr, introduce, cosponsor, passage, protection, week, ensure, transparency, introducing, accountability'
#  'Ideal Point = 0.5, Topic = 19: act, passed, bipartisan, legislation, proud, introduced, voted, protect, pass, hr, help, accountability, abortion, passage, protection, week, transparency, passes, introduce, protection act'
#  'Ideal Point = 1.0, Topic = 19: abortion, act, passed, bipartisan, legislation, regulatory, born alive, born, alive, child, voted, accountability, unborn, protect, introduced, proud, hr, reforms, protection act, passage'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 20: en, para, immigration, que, reform, por, un, es, del, con, sobre, justice, una, comprehensive, su, step, cuba, system, este, gracias'
#  'Ideal Point = -0.5, Topic = 20: en, immigration, reform, step, system, para, que, con, por, del, justice, un, comprehensive, es, immigration reform, toward, su, una, towards, criminal'
#  'Ideal Point = 0.0, Topic = 20: step, system, reform, immigration, toward, en, towards, broken, con, closer, justice, immigration reform, important, para, direction, que, first, criminal, fix, del'
#  'Ideal Point = 0.5, Topic = 20: step, system, toward, towards, broken, first, closer, ly, important, direction, reform, immigration, ow, ow ly, fixing, first step, important step, fix, took, step closer'
#  'Ideal Point = 1.0, Topic = 20: step, system, first, ly, ow ly, ow, broken, toward, towards, important, fixing, direction, closer, took, step closer, first step, important step, fix, step towards, moving'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 21: women, health, care, abortion, health care, access, reproductive, women health, affordable, woman, ppfa, control, disparities, birth, affordable care, birth control, services, affordable care act, essential, reproductive health'
#  'Ideal Point = -0.5, Topic = 21: health, care, health care, access, women, affordable, services, healthcare, mental, affordable care, women health, medical, mental health, affordable care act, reproductive, abortion, essential, control, care act, americans'
#  'Ideal Point = 0.0, Topic = 21: health, care, health care, access, healthcare, affordable, services, medical, mental, improve, patients, mental health, women, care act, ensure, act, centers, expand, hospital, system'
#  'Ideal Point = 0.5, Topic = 21: health, care, health care, access, healthcare, medical, services, patients, improve, affordable, hospital, mental, patient, centers, american, doctors, system, care act, mental health, community'
#  'Ideal Point = 1.0, Topic = 21: care, health, health care, healthcare, access, medical, american, patients, health care law, care law, improve, patient centered, health care act, patient, hospital, rural, centered, services, reforms, american health care'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 22: income, low, inequality, low income, cost, housedemocrats, companies, prescription, costs, americans, drug, afford, lower, drug prices, drugs, families, pharma, prescription drugs, rising, prices'
#  'Ideal Point = -0.5, Topic = 22: income, low, cost, drug, costs, prescription, lower, low income, drugs, prices, americans, prescription drugs, rising, drug prices, companies, afford, prescription drug, families, inequality, housedemocrats'
#  'Ideal Point = 0.0, Topic = 22: drug, cost, costs, lower, prescription, prices, low, drugs, income, prescription drug, rising, low income, prescription drugs, americans, drug prices, families, drug costs, lowering, medicine, afford'
#  'Ideal Point = 0.5, Topic = 22: drug, cost, costs, lower, prices, prescription, drugs, site, prescription drug, low, device, rising, drop, near, prescription drugs, lower costs, medical device, income, gas prices, drug abuse'
#  'Ideal Point = 1.0, Topic = 22: drug, site, costs, cost, device, prices, device tax, near, lower, medical device, drop, medical device tax, gas prices, collection, prescription, medical, drugs, drug abuse, location, safely'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 23: debt, student, senwarren, financial, free, loans, trust, open internet, rates, open, internet, profit, loan, predatory, protect, rules, consumers, fcc, student loan, student debt'
#  'Ideal Point = -0.5, Topic = 23: free, student, debt, internet, financial, loan, consumers, loans, fcc, open, data, rates, protect, student loan, rules, profit, open internet, trust, senwarren, consumer'
#  'Ideal Point = 0.0, Topic = 23: free, student, internet, consumers, data, loan, fcc, trafficking, financial, debt, cfpb, protect, privacy, student loan, open, consumer, practices, rules, loans, speech'
#  'Ideal Point = 0.5, Topic = 23: free, human, trafficking, internet, data, human trafficking, student, consumers, loan, speech, privacy, cfpb, fcc, sex, online, practices, net, google, protect, dodd'
#  'Ideal Point = 1.0, Topic = 23: human, free, trafficking, human trafficking, sex, data, dodd, internet, modern, speech, consumers, sex trafficking, privacy, cfpb, slavery, student, google, online, loan, traffickers'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 24: jecdems, shows, job, deal, private, half, tpp, economic, trade, uninsured rate, population, rate, poll, nafta, federalreserve, trade war, tariffs, bad, growth, added'
#  'Ideal Point = -0.5, Topic = 24: job, shows, deal, private, economic, trade, half, growth, rate, jecdems, since, tpp, added, population, nafta, numbers, unemployment, sector, highest, jobs'
#  'Ideal Point = 0.0, Topic = 24: job, trade, economic, growth, jobs, since, private, economy, rate, deal, shows, unemployment, american, added, half, highest, economic growth, numbers, workers, created'
#  'Ideal Point = 0.5, Topic = 24: jobs, economy, job, growth, trade, american, economic, since, workers, pro, policies, regulations, usmca, unemployment, america, americans, wages, pro growth, rate, growing'
#  'Ideal Point = 1.0, Topic = 24: jobs, economy, pro, pro growth, american, regulations, workers, growth, policies, americans, grow, wages, usmca, america, million, trade, businesses, job, since, low'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 25: sign, open, please, find, enrollment, census, open enrollment, visit, coveredca, plan, still, information, help, online, deadline, left, renewal, enroll, apply, info'
#  'Ideal Point = -0.5, Topic = 25: visit, open, please, find, sign, information, info, help, apply, enrollment, deadline, learn, census, open enrollment, online, still, someone, available, register, plan'
#  'Ideal Point = 0.0, Topic = 25: visit, please, open, find, information, info, learn, help, apply, deadline, website, click, someone, sign, interested, academy, contact, enrollment, available, offices'
#  'Ideal Point = 0.5, Topic = 25: visit, please, find, information, open, info, learn, click, academy, website, link, interested, help, apply, district, offices, summer, contact, list, deadline'
#  'Ideal Point = 1.0, Topic = 25: visit, click, please, information, academy, learn, find, info, open, website, link, military, summer, interested, district, list, survey, academies, offices, apply'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 26: rights, equality, lgbt, lgbtq, fight, discrimination, voting rights, human, civil rights, voting, civil, women, trans, anniversary, voter, equal, transgender, democracy, gender, americans'
#  'Ideal Point = -0.5, Topic = 26: rights, voting, equality, human, discrimination, fight, civil, lgbt, lgbtq, civil rights, voting rights, anniversary, voter, americans, democracy, human rights, equal, women, voters, transgender'
#  'Ideal Point = 0.0, Topic = 26: rights, voting, civil, human, equality, discrimination, civil rights, fight, human rights, americans, anniversary, race, lgbtq, voter, democracy, lgbt, voting rights, voters, proud, movement'
#  'Ideal Point = 0.5, Topic = 26: rights, voting, civil, human, race, human rights, liberties, discrimination, fundamental, civil rights, asset, americans, exercise, box, basic, equality, anniversary, voters, cast, proud'
#  'Ideal Point = 1.0, Topic = 26: voting, rights, asset, liberties, civil, ratified, race, exercise, human, kong, hong kong, hong, american, fundamental, box, human rights, cast, week, state, georgians'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 27: gun, gun violence, violence, laws, lives, demand, silence, safety, victims, guns, epidemic, gun safety, mass, nra, weapons, shooting, sit, end, since, prevention'
#  'Ideal Point = -0.5, Topic = 27: gun, violence, gun violence, laws, prevent, safety, lives, save, mass, guns, domestic, nra, common, victims, silence, end, prevention, demand, since, gun safety'
#  'Ideal Point = 0.0, Topic = 27: violence, gun, save, prevent, gun violence, common, domestic, safety, lives, mass, laws, save lives, guns, nra, communities, help, end, prevention, stop, control'
#  'Ideal Point = 0.5, Topic = 27: save, violence, prevent, common, gun, control, domestic, help, save lives, gun violence, safety, mass, help prevent, lives, ground, gun control, stop, communities, laws, guns'
#  'Ideal Point = 1.0, Topic = 27: save, common, prevent, control, violence, help, ground, help prevent, gun, domestic, save lives, violence act, gun control, common ground, week, congressman, safety, spoke, together, stop'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 28: trumpcare, americans, gop, aca, millions, protections, healthcare, republicans, pre existing, million, conditions, health, pre, away, existing, pre existing conditions, existing conditions, coverage, senategop, lose'
#  'Ideal Point = -0.5, Topic = 28: americans, aca, trumpcare, million, millions, gop, conditions, coverage, pre, healthcare, pre existing, protections, insurance, existing, health, lose, pre existing conditions, existing conditions, away, repeal'
#  'Ideal Point = 0.0, Topic = 28: americans, million, insurance, millions, aca, repeal, coverage, obamacare, conditions, plans, pre, existing, gop, plan, lose, health insurance, health, healthcare, pre existing, trumpcare'
#  'Ideal Point = 0.5, Topic = 28: obamacare, repeal, million, insurance, americans, plans, plan, coverage, millions, premiums, delay, aca, replace, mandate, health insurance, individual, conditions, voted, higher, ahca'
#  'Ideal Point = 1.0, Topic = 28: obamacare, delay, repeal obamacare, repeal, choices, mandate, mandates, promise, plans, replace, exchange, insurance, million, individual, defund, failing, employer, premiums, plan, forbes'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 29: oversightdems, trump, housejuddems, democracy, russia, investigation, constitution, breaking, power, ag, housejudiciary, white, foreign, elections, flynn, election, mueller, gop, commission, campaign'
#  'Ideal Point = -0.5, Topic = 29: trump, oversightdems, investigation, russia, election, democracy, realdonaldtrump, mueller, power, campaign, truth, elections, white, constitution, hold, foreign, political, russian, says, special'
#  'Ideal Point = 0.0, Topic = 29: trump, realdonaldtrump, investigation, impeachment, election, hold, general, russia, political, potus, mueller, accountable, american, fbi, campaign, truth, process, special, facts, asked'
#  'Ideal Point = 0.5, Topic = 29: democrats, impeachment, realdonaldtrump, irs, trump, process, gopoversight, general, potus, fbi, american, hold, investigation, accountable, political, clinton, election, admin, potus realdonaldtrump, benghazi'
#  'Ideal Point = 1.0, Topic = 29: irs, democrats, admin, gopoversight, impeachment, potus realdonaldtrump, benghazi, realdonaldtrump, dems, process, clinton, lerner, targeting, media, general, conservatives, potus, impeach, sham, fisa'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 30: senschumer, sengillibrand, cont, law, interests, special interests, body, special, signed, enforcement, supporting, push, continuing, police, forced, law enforcement, completion, cameras, officers, carry'
#  'Ideal Point = -0.5, Topic = 30: law, signed, enforcement, senschumer, police, sengillibrand, law enforcement, interests, officers, special, special interests, cont, body, carry, finance, becomes, supporting, continuing, local, protect'
#  'Ideal Point = 0.0, Topic = 30: law, signed, enforcement, law enforcement, police, officers, carry, interests, special, police officers, finance, enforcement officers, special interests, law enforcement officers, local, potus, state, communities, protect, becomes'
#  'Ideal Point = 0.5, Topic = 30: law, signed, enforcement, law enforcement, officers, police, potus, cities, sanctuary, carry, enforcement officers, law enforcement officers, police officers, capitol police, communities, sanctuary cities, local, chief, state, potus signed'
#  'Ideal Point = 1.0, Topic = 30: law, signed, enforcement, law enforcement, potus, cities, officers, police, sanctuary, sanctuary cities, enforcement officers, law enforcement officers, potus signed, capitol police, kate, law abiding, carry, communities, abiding, police officers'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 31: public, health, crisis, public health, crises, health crises, public health crisis, health crisis, tobacco, servants, front, public servants, epidemic, combat, public safety, lines, opioid, american public, addiction, safety'
#  'Ideal Point = -0.5, Topic = 31: public, crisis, public health, health, combat, opioid, epidemic, front, lines, health crisis, addiction, communities, public health crisis, servants, safety, public safety, crises, opioid epidemic, public servants, broadband'
#  'Ideal Point = 0.0, Topic = 31: public, crisis, opioid, combat, epidemic, public health, front, communities, rural, lines, addiction, abuse, broadband, opioid epidemic, fight, help, safety, opioid crisis, health, front lines'
#  'Ideal Point = 0.5, Topic = 31: public, opioid, crisis, combat, rural, communities, abuse, fight, epidemic, front, broadband, opioid epidemic, help, addiction, lines, opioid crisis, week, rural communities, treatment, heroin'
#  'Ideal Point = 1.0, Topic = 31: opioid, rural, abuse, fight, combat, communities, public, broadband, epidemic, crisis, help, opioid epidemic, front, opioid crisis, week, rural communities, areas, combating, addiction, opioid abuse'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 32: nrdems, climate, climate change, change, flint, clean, protect, science, air, trump, climatecrisis, planet, pollution, environment, bold, generations, water, pruitt, lcvoters, communities'
#  'Ideal Point = -0.5, Topic = 32: change, climate, water, climate change, clean, protect, environment, nrdems, science, air, energy, epa, environmental, communities, flint, planet, generations, pollution, lead, trump'
#  'Ideal Point = 0.0, Topic = 32: water, change, energy, epa, climate, clean, environment, protect, climate change, land, power, oil, environmental, gas, natural, science, communities, impacts, air, lands'
#  'Ideal Point = 0.5, Topic = 32: energy, water, epa, natresources, change, power, land, westerncaucus, regulation, coal, regs, clean, gas, western, oil, production, forest, natural, management, environment'
#  'Ideal Point = 1.0, Topic = 32: westerncaucus, natresources, energy, regulation, regs, american energy, power, epa, production, water, era, coal, forest, western, management, resources, land, transportgop, costly, infrastructure'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 33: family, friends, victims, families, neighbors, heart, loved, ones, thoughts, community, loved ones, goes, first, tragedy, responders, shooting, entire, life, first responders, difficult'
#  'Ideal Point = -0.5, Topic = 33: family, friends, victims, families, thoughts, loved, heart, first, ones, prayers, loved ones, neighbors, responders, community, entire, first responders, goes, tragedy, shooting, difficult'
#  'Ideal Point = 0.0, Topic = 33: family, thoughts, families, victims, friends, prayers, first, loved, ones, heart, responders, loved ones, first responders, entire, community, goes, loss, neighbors, affected, shooting'
#  'Ideal Point = 0.5, Topic = 33: family, prayers, thoughts, families, first, victims, friends, praying, loved, god, responders, ones, first responders, heart, bless, entire, loved ones, god bless, attack, pray'
#  'Ideal Point = 1.0, Topic = 33: family, prayers, thoughts, bless, god, god bless, praying, first, families, victims, please, friends, pray, half, loved, responders, flags, first responders, ones, entire'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 34: hate, war, racist, white, anti, trump, bigotry, racism, crimes, hateful, comments, deeply, saudi, yemen, jewish, protest, rise, world, hate crimes, xenophobia'
#  'Ideal Point = -0.5, Topic = 34: war, hate, anti, white, world, trump, racist, attacks, international, bigotry, global, racism, allies, iran, jewish, israel, countries, peace, nuclear, crimes'
#  'Ideal Point = 0.0, Topic = 34: war, iran, anti, world, israel, nuclear, attacks, syria, international, hate, foreign, potus, allies, global, threat, china, terrorism, countries, isis, realdonaldtrump'
#  'Ideal Point = 0.5, Topic = 34: iran, deal, israel, isis, world, foreign, nuclear, china, threat, potus, america, syria, terrorism, policy, househomeland, anti, attacks, terrorist, terror, sanctions'
#  'Ideal Point = 1.0, Topic = 34: deal, househomeland, iran, applaud, isis, israel, freebeacon, china, america, foreign, threat, terrorists, potus, nuclear, terrorist, iranian, russia, policy, houseforeigngop, terrorism'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 35: national, security, homelanddems, clearance, national security, security clearance, hascdemocrats, parks, kushner, defense, monuments, potus, nat, coast, protect, fees, national parks, monument, national monuments, homeland security'
#  'Ideal Point = -0.5, Topic = 35: national, security, national security, defense, parks, homelanddems, nat, clearance, coast, hascdemocrats, guard, security clearance, homeland, homeland security, cyber, national parks, potus, base, monuments, monument'
#  'Ideal Point = 0.0, Topic = 35: national, security, defense, national security, parks, guard, nat, homeland, military, cyber, coast, homeland security, ndaa, cybersecurity, readiness, week, national guard, base, authorization, deptofdefense'
#  'Ideal Point = 0.5, Topic = 35: national, security, defense, national security, military, ndaa, guard, homeland, readiness, hascrepublicans, national defense, cyber, hasc, cybersecurity, nat, national guard, authorization, parks, homeland security, dod'
#  'Ideal Point = 1.0, Topic = 35: national, defense, security, hascrepublicans, military, ndaa, hasc, national security, guard, national defense, readiness, homeland, troops, aircraft, national guard, cybersecurity, authorization, america, cyber, authorization act'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 36: ty, community, impt, discuss, meeting, issues, advocates, met, abt, important, panel, ways, conversation, forum, priorities, importance, delegation, discussion, facing, experts'
#  'Ideal Point = -0.5, Topic = 36: meeting, discuss, issues, community, met, important, discussion, importance, ways, priorities, conversation, ty, forum, panel, facing, advocates, challenges, members, yesterday, officials'
#  'Ideal Point = 0.0, Topic = 36: meeting, discuss, issues, met, important, discussion, importance, community, ways, members, yesterday, priorities, conversation, discussed, facing, forum, challenges, stopping, appreciate, board'
#  'Ideal Point = 0.5, Topic = 36: meeting, discuss, issues, met, discussion, important, members, yesterday, importance, discussed, stopping, appreciate, ways, priorities, legislative, association, conversation, enjoyed, roundtable, community'
#  'Ideal Point = 1.0, Topic = 36: meeting, issues, discuss, met, discussion, members, yesterday, enjoyed, discussed, stopping, important, appreciate, association, legislative, discussing, importance, enjoyed meeting, roundtable, ways, representatives'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 37: jobs, background, background checks, checks, creating, infrastructure, buy, housedemocrats, universal, good, create, america, terrorists, paying, let, universal background, loophole, universal background checks, roads, suspected'
#  'Ideal Point = -0.5, Topic = 37: jobs, infrastructure, create, background, checks, background checks, creating, paying, good, universal, america, buy, roads, invest, let, bridges, transportation, loophole, universal background, investing'
#  'Ideal Point = 0.0, Topic = 37: jobs, create, infrastructure, paying, background, checks, create jobs, transportation, creating, background checks, america, good, invest, roads, bridges, paying jobs, universal, good paying, buy, good paying jobs'
#  'Ideal Point = 0.5, Topic = 37: create, infrastructure, jobs, create jobs, pipeline, paying, keystone, transportation, approve, checks, background, paying jobs, good paying, invest, export, help, bridges, xl, creating, build'
#  'Ideal Point = 1.0, Topic = 37: pipeline, keystone, create, approve, infrastructure, create jobs, xl, jobs, paying, transportation, state, build, help, paying jobs, export, approval, projects, good paying, infrastructure projects, nation'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 38: town, hall, town hall, rsvp, questions, answer, tweet, facebook, hosting, monday, hope, using, townhall, facebook live, question, tonight, saturday, next, virtual, telephone'
#  'Ideal Point = -0.5, Topic = 38: town, hall, town hall, questions, answer, tweet, rsvp, hosting, question, hope, tonight, townhall, telephone, monday, next, telephone town, facebook, constituents, telephone town hall, hear'
#  'Ideal Point = 0.0, Topic = 38: town, hall, town hall, questions, answer, question, hosting, tweet, tonight, telephone, hope, meeting, night, townhall, telephone town, telephone town hall, next, constituents, town hall meeting, hall meeting'
#  'Ideal Point = 0.5, Topic = 38: town, hall, questions, town hall, answer, question, meeting, tonight, night, telephone, town hall meeting, hall meeting, hosting, meetings, hope, telephone town, telephone town hall, comments, halls, townhall'
#  'Ideal Point = 1.0, Topic = 38: hall, town, questions, town hall, meeting, comments, question, hall meeting, town hall meeting, meetings, answer, night, tonight, telephone, halls, hosting, telephone town, telephone town hall, looking, folks'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 39: safety net, program, snap, net, bolster, count, cut, key, safety, housegop, realdonaldtrump, housedemocrats, gop, another, republicans, days, yet, democrats, dems, put'
#  'Ideal Point = -0.5, Topic = 39: housegop, another, democrats, days, republicans, put, yet, gop, realdonaldtrump, housedemocrats, dems, safety, cut, count, key, program, republican, snap, net, safety net'
#  'Ideal Point = 0.0, Topic = 39: another, put, democrats, days, republicans, yet, republican, politics, housegop, dems, gop, term, party, instead, votes, majority, partisan, solution, americans, speaker'
#  'Ideal Point = 0.5, Topic = 39: another, put, democrats, days, republicans, speakerboehner, speaker, politics, republican, yet, votes, term, partisan, pass, problems, solution, solutions, instead, party, problem'
#  'Ideal Point = 1.0, Topic = 39: gopconference, speakerboehner, speaker, another, bureaucrats, put, veto, democrats, politics, votes, solutions, days, republicans, problems, republican, socialist, democrat, term, pass, problem'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 40: money, federal, government, trump, employees, wall, shutdown, taxpayers, fund, federal workers, workers, realdonaldtrump, ineffective, funds, ridiculous, hundreds, shut, pay, fully, dollars'
#  'Ideal Point = -0.5, Topic = 40: government, federal, money, shutdown, wall, fund, border, employees, trump, funds, dollars, fed, realdonaldtrump, taxpayer, fully, secure, taxpayers, shut, govt, federal workers'
#  'Ideal Point = 0.0, Topic = 40: government, federal, border, shutdown, fund, wall, money, secure, fed, taxpayer, dollars, govt, funds, southern, employees, funding, fully, federal government, gov, end'
#  'Ideal Point = 0.5, Topic = 40: government, border, immigration, federal, secure, illegal, funding, laws, fund, southern, shutdown, govt, crisis, taxpayer, fed, wall, security, dollars, federal government, border security'
#  'Ideal Point = 1.0, Topic = 40: immigration, laws, border, government, crisis, illegal, security, secure, funding, borders, immigrants, illegal immigration, democrats, southern, immigration laws, enforce, illegal immigrants, govt, amnesty, federal'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 41: colleagues, demanding, joined, calling, democratic, letter, states, united, urging, led, housedemocrats, united states, sent, dem, proud, asking, gop colleagues, potus, realdonaldtrump, members'
#  'Ideal Point = -0.5, Topic = 41: colleagues, joined, letter, states, calling, united, united states, demanding, led, urging, sent, asking, democratic, members, wrote, proud, priority, sent letter, potus, delegation'
#  'Ideal Point = 0.0, Topic = 41: joined, colleagues, states, letter, united, united states, calling, sent, led, urging, asking, top, priority, delegation, members, sent letter, wrote, demanding, proud, potus'
#  'Ideal Point = 0.5, Topic = 41: joined, states, colleagues, united, letter, top, united states, sent, led, priority, calling, asking, delegation, urging, sent letter, members, top priority, yesterday, wrote, icymi'
#  'Ideal Point = 1.0, Topic = 41: top, states, joined, united, united states, colleagues, letter, sent, priority, delegation, led, asking, signing, top priority, calling, yesterday, urging, icymi, secretary, congressmen'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 42: officialcbc, usprogressives, capac, chair, survivors, sexual, housedemwomen, assault, progressive, cbc, harassment, vice, sexual harassment, vice chair, members, caucus, sexual assault, founding, proud, repmikehonda'
#  'Ideal Point = -0.5, Topic = 42: officialcbc, chair, sexual, caucus, assault, usprogressives, survivors, harassment, capac, members, sexual assault, sexual harassment, vice, progressive, cbc, proud, housedemwomen, vice chair, red, founding'
#  'Ideal Point = 0.0, Topic = 42: caucus, sexual, chair, assault, red, sexual assault, members, officialcbc, harassment, problem, proud, tape, survivors, chairs, sexual harassment, red tape, vice, solvers, problem solvers, end'
#  'Ideal Point = 0.5, Topic = 42: caucus, red, tape, red tape, freedomcaucus, sexual, chair, assault, problem, cut, sexual assault, solvers, members, problem solvers, chairs, proud, solvers caucus, problem solvers caucus, freedom caucus, bureaucratic'
#  'Ideal Point = 1.0, Topic = 42: freedomcaucus, red, red tape, tape, caucus, cut, freedom caucus, bureaucratic, cut red tape, cut red, solvers, problem solvers, problem, solvers caucus, problem solvers caucus, sexual, chair, assault, sexual assault, nolabelsorg'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 43: residents, santa, transportdems, fire, ventura, county, miami, bay, bay area, transit, ventura county, riders, bus, update, safety, area, train, project, clara, fires'
#  'Ideal Point = -0.5, Topic = 43: county, residents, fire, update, area, project, santa, bay, road, safety, transportdems, transit, weather, miami, closed, bus, ventura, train, station, evacuation'
#  'Ideal Point = 0.0, Topic = 43: county, update, fire, residents, area, project, road, weather, safety, closed, due, river, bay, state, station, bridge, airport, alert, storm, local'
#  'Ideal Point = 0.5, Topic = 43: county, update, area, fire, project, residents, weather, road, transport, river, due, storm, counties, department, closed, state, flood, local, sheriff, damage'
#  'Ideal Point = 1.0, Topic = 43: county, update, transport, area, fire, counties, river, project, storm, weather, flood, tornado, department, due, bend, sheriff, road, damage, state, aviation'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 44: hiv, aids, research, life, hiv aids, awareness, cancer, raise, disease, early, start, head, cause, pregnancy, saving, dying, suicide, prevention, stigma, death'
#  'Ideal Point = -0.5, Topic = 44: research, awareness, cancer, hiv, early, head, aids, disease, life, cause, saving, start, raise, suicide, prevention, diabetes, nih, death, fight, hiv aids'
#  'Ideal Point = 0.0, Topic = 44: research, cancer, awareness, early, head, saving, disease, cause, start, suicide, raise, prevention, alzheimer, help, life, raise awareness, nih, diabetes, cures, life saving'
#  'Ideal Point = 0.5, Topic = 44: research, cancer, awareness, century, early, head, cures, saving, disease, cause, suicide, help, start, alzheimer, prevention, century cures, raise, raise awareness, childhood, eccures'
#  'Ideal Point = 1.0, Topic = 44: century, cures, eccures, cancer, research, century cures, awareness, early, head, cures act, century cures act, saving, childhood cancer, hope, help, alzheimer, disease, cause, childhood, suicide'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 45: tax, gop, corporations, republicans, wealthy, families, cuts, rich, americans, tax cuts, cut, taxes, plan, wealthiest, trillion, give, corporate, deficit, tax breaks, middle'
#  'Ideal Point = -0.5, Topic = 45: tax, families, gop, class, middle, corporations, cut, middle class, plan, taxes, americans, cuts, wealthy, republicans, rich, tax cuts, give, corporate, trillion, breaks'
#  'Ideal Point = 0.0, Topic = 45: class, tax, middle, families, middle class, break, plan, cut, street, gop, taxes, americans, massive, corporations, give, cuts, class families, main, middle class families, rich'
#  'Ideal Point = 0.5, Topic = 45: class, middle, street, main, break, middle class, main street, tax, families, massive, plan, cut, hike, class families, middle class families, taxes, freshman, state, left, tax hike'
#  'Ideal Point = 1.0, Topic = 45: class, main, main street, street, middle, break, middle class, hike, bailouts, tax hike, freshman, massive, state, families, class families, first, tax, middle class families, left, world class'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 46: women, girls, wage, color, men, pay, equal, gap, moms, white, less, act, average, minimum wage, workers, let, minimum, hispanic, paid, leave'
#  'Ideal Point = -0.5, Topic = 46: women, pay, wage, color, paid, girls, equal, leave, men, gap, workers, minimum, minimum wage, still, let, white, less, average, equal pay, sick'
#  'Ideal Point = 0.0, Topic = 46: pay, women, paid, leave, field, equal, wage, paycheck, raise, level, minimum, workers, fairness, playing, still, gap, dollar, minimum wage, let, earn'
#  'Ideal Point = 0.5, Topic = 46: pay, raise, field, paycheck, paid, troops, leave, protection, program, playing, paycheck protection, level, protection program, paycheck protection program, largest, pay raise, biggest, give, playing field, women'
#  'Ideal Point = 1.0, Topic = 46: troops, program, largest, raise, biggest, pay raise, paycheck protection, protection, protection program, pay, field, paycheck protection program, paycheck, playing, businesses, paid, give, level, leave, playing field'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 47: return, tax returns, returns, payments, card, credit, mnuchin, irs, direct, zip, waysmeanscmte, file, potus, zip code, release, stimulus, still, payment, receive, treasury'
#  'Ideal Point = -0.5, Topic = 47: return, returns, credit, tax returns, payments, tax, irs, file, card, payment, direct, receive, code, tax credit, filing, mnuchin, impact, treasury, potus, zip'
#  'Ideal Point = 0.0, Topic = 47: tax, credit, code, reform, payments, irs, file, returns, return, taxes, tax code, money, families, payment, taxpayers, tax credit, tax returns, receive, tax reform, americans'
#  'Ideal Point = 0.5, Topic = 47: tax, reform, tax reform, taxes, cuts, waysandmeansgop, americans, jobs, code, tax cuts, tax code, families, money, taxpayers, jobs act, plan, act, credit, employees, paychecks'
#  'Ideal Point = 1.0, Topic = 47: waysandmeansgop, tax, reform, tax reform, jobs, cuts, tax cuts, taxes, americans, jobs act, tax code, act, paychecks, plan, families, hardworking, code, money, lower, taxpayers'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 48: yorkers, fighting, keep, safe, nygovcuomo, keep fighting, stay, home, healthy, spread, hands, everyone, cases, avoid, keep guns, stop, help, keeping, word, governortomwolf'
#  'Ideal Point = -0.5, Topic = 48: keep, safe, stay, fighting, home, spread, healthy, hands, keep fighting, keeping, everyone, help, word, cases, avoid, yorkers, communities, nygovcuomo, let, cdcgov'
#  'Ideal Point = 0.0, Topic = 48: keep, safe, stay, keeping, spread, healthy, home, hands, fighting, help, word, everyone, cases, avoid, stay safe, tips, cdcgov, communities, let, keep fighting'
#  'Ideal Point = 0.5, Topic = 48: keep, safe, stay, keeping, spread, healthy, hands, help, home, word, stay safe, americans, way, tips, please, everyone, cdcgov, informed, let, avoid'
#  'Ideal Point = 1.0, Topic = 48: keep, safe, keeping, stay, promise, americans, spread, healthy, stay safe, help, america, word, hands, way, dougducey, home, please, store, tips, keep america'
#  '========================================================================================================================'
#  'Ideal Point = -1.0, Topic = 49: rm, hfacdemocrats, hfacdemocrats rm, speaking, appropsdems, edworkforcedems, live, housedemocrats, energycommerce, watch, press, repbobbyscott, fscdems, conference, happening, press conference, reporters, subcommittee, watch live, free press'
#  'Ideal Point = -0.5, Topic = 49: live, watch, speaking, hfacdemocrats, press, rm, conference, happening, appropsdems, hfacdemocrats rm, press conference, energycommerce, watch live, edworkforcedems, subcommittee, housedemocrats, fscdems, repbobbyscott, appropriations, starting'
#  'Ideal Point = 0.0, Topic = 49: watch, live, conference, press, watch live, happening, speaking, subcommittee, appropriations, press conference, markup, joint, starting, full, release, cmte, housecommerce, video, housefloor, soon'
#  'Ideal Point = 0.5, Topic = 49: watch, live, housecommerce, video, watch live, conference, houseappropsgop, financialcmte, subcommittee, happening, press, appropriations, chair, full, markup, joint, housejudiciary, oversight, smallbizgop, sec'
#  'Ideal Point = 1.0, Topic = 49: housecommerce, video, financialcmte, smallbizgop, watch, houseappropsgop, housejudiciary, chair, live, watch live, oversight, full, vice, rulesreps, sec, subcommittee, conference, repblainepress, appropriations, markup'
#  '========================================================================================================================']

# %%
# %%capture cap --no-stderr
utils.print_topics(objective_topic_loc, 
                   objective_topic_scale, 
                   ideological_topic_loc, 
                   ideological_topic_scale, 
                   vocabulary, 
                   20)
with open('../../tweets_results/topics.txt', 'w') as f:
    f.write(cap.stdout)

# %%
bid_to_twitter_uid = pickle.load(open(os.path.join(source_dir,'social_media_data_bioguide_to_twitter.pkl'), 'rb'))
print(len(bid_to_twitter_uid))
twitter_uid_to_bid = {v:k for k,v in bid_to_twitter_uid.items()}
# Out:
# 530

# %%
legis_info = json.load(open('../data/floor_speeches_congs_115_116/legislator-info-1990-2020.json'))
print(len(legis_info))
# Out:
# 1880

# %%
legis_id_to_info = {}
for x in legis_info:
    legis_id_to_info[x['id']['bioguide']] = x

# %%
parties = []
for a in author_map:
    x = legis_id_to_info[twitter_uid_to_bid[int(a)]]
    parties.append(x['terms'][-1]['party'])
print(len(parties))
# Out:
# 471

# %%
names = []
for a in author_map:
    x = legis_id_to_info[twitter_uid_to_bid[int(a)]]
    names.append(x['id']['wikipedia'])
print(len(names))
# Out:
# 471

# %%
colors = np.array(["steelblue" if p=='Democrat' else "crimson" for p in parties])
def get_ideological_topics(objective_topic_loc, 
                           objective_topic_scale,
                           ideological_topic_loc, 
                           ideological_topic_scale,
                           ideal_point):
    ideological_topic_mean = np.exp(objective_topic_loc +
                              ideal_point * ideological_topic_loc +
                              (objective_topic_scale ** 2 + 
                               ideal_point ** 2 * 
                               ideological_topic_scale ** 2) / 2)
    return ideological_topic_mean

# %%
ideal_points = ideal_point_mean
author_map = np.array(author_map)
print(author_map.shape)
ideal_points = np.array(ideal_points)
print(ideal_points.shape)
# Out:
# (471,)
# (471,)

# %%
bid_to_tbip = {}
for i in range(len(author_map)):
    bid_to_tbip[twitter_uid_to_bid[int(author_map[i])]] = ideal_points[i]
print(len(bid_to_tbip))
# Out:
# 471

# %%
pickle.dump(bid_to_tbip, 
            open('../../tweets_results/bid_to_tbip_tweets.pkl', 'wb'))

# %%
import chart_studio
chart_studio.tools.set_credentials_file(username='pg96', api_key='NDcsdaKUnDc6rrurwLmg')
import chart_studio.plotly as py

# %%
def save_interactive(topic_number):
    topic_name = 'Topic ' + str(topic_number)

    fig = go.Figure(layout = go.Layout(
        paper_bgcolor='rgba(0,0,0,0)',
        plot_bgcolor='rgba(0,0,0,0)'))
    x_min = -1.0
    x_max = 1.0
    diff = 0.05
    offset = -x_min / diff
    scatterplot_location = -0.53

    ideal_point_dict = {}
    for i in range(int((x_max - x_min) / diff) + 1):
        ideal_point_dict[i] = (i - offset) * diff

    # Add black line.
    fig.add_trace(go.Scatter(x=[x_min, x_max], 
                             y = [scatterplot_location, scatterplot_location],
                             line=dict(color="black", width=1),
                             marker=dict(size=1),
                             hoverinfo='skip'))

    # Add trace for all representatives
    fig.add_trace(go.Scatter(
        mode="markers",
        x=ideal_points, 
        y=scatterplot_location * np.ones(len(ideal_points)), 
        text=[x for x in names], 
        hoverinfo="x+text",
        marker=dict(color=colors, size=8)))

    num_top_words = 10

    # Add bar plots, one for each ideal point
    for step in np.arange(len(ideal_point_dict.keys())):
        ideological_topic_mean = get_ideological_topics(objective_topic_loc, 
                                   objective_topic_scale,
                                   ideological_topic_loc, 
                                   ideological_topic_scale,
                                   ideal_point_dict[step])
        topic_intensities = ideological_topic_mean[topic_number]
        top_topic_intensities = np.sort(topic_intensities)[-num_top_words:]
        top_topic_words = vocabulary[np.argsort(-topic_intensities)[:num_top_words]][::-1]
        fig.add_trace(
            go.Bar(
                visible=False,
                x=top_topic_intensities * 5,
                orientation='h',
                text=top_topic_words,
                textposition='outside',
                marker_color='rgb(175,122,197)',
                y0=0.529,
                dy=0.214,
                base=-0.3,
                hoverinfo='skip',
            ))

    fig.update_layout(go.Layout(
    yaxis = {'showgrid': False,
             'showline': False,
             'zeroline': False,
            'showticklabels': False,
            'fixedrange': True}),
    xaxis = {'showgrid': False,
             'showline': False,
             'zeroline': False,
            'showticklabels': False,
            'fixedrange': True})
    fig.update_yaxes(range=[-0.60, 2.5])
    fig.update_xaxes(range=[x_min - 0.01, x_max + 0.02])

    # Set default trace
    fig.data[len(fig.data) // 2].visible = True

    # Create and add slider
    steps = []
    for i in range(2, len(fig.data)):
        step = dict(
            method="update",
            args=[{"visible": [True, True] + [False] * (len(fig.data) - 2)}],  
            label="{:.2f}".format(ideal_point_dict[i - 2]),
        )
        step["args"][0]["visible"][i] = True  # Toggle i'th trace to "visible"
        steps.append(step)

    sliders = [dict(
        active=(len(fig.data) // 2 - 1),
        currentvalue={"prefix": "Ideal Point: "},
        y=0.35,
        steps=steps)]

    fig.update_layout(sliders=sliders, showlegend=False, 
                      title={'text': "Word Usage as a Function of Ideal Point (Topic: {})".format(topic_name),
                             'x': 0.5,
                             'y': 0.9},
                      xaxis_title='Representative ideal points (hover to see names)',
                      annotations = [
                                    dict(xref='paper',
                                            yref='paper',
                                            x=0.5, y=0.255,
                                            font={'size': 14},
                                            showarrow=False,
                                            text ='Move slider to change ideal point')
                      ])
    #fig.show()
    fig.write_html("../../tweets_results/interactive_htmls/topic" + str(topic_number) + "_interactive.html")

# %%
num_topics = objective_topic_mean.shape[0]
print(num_topics)
# Out:
# 50

# %%
for topic_ind in range(num_topics):
    save_interactive(topic_ind)

# %%
print(document_mean.shape)
# Out:
# (295327, 50)

# %%
tweets_data = pd.read_csv(os.path.join(source_dir, "finalized_tbip_tweets_sampled2.csv"))
print(tweets_data.info())
tweets_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295327 entries, 0 to 295326
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Tweet ID   295327 non-null  int64
#  1   Author ID  295327 non-null  int64
#  2   Text       295327 non-null  object
#  3   Timestamp  295327 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 9.0+ MB
# None
#               Tweet ID           Author ID  \
# 0   996837967976194048  818554054309715969
# 1   878358077145325569  818554054309715969
# 2   979935734701412353  818554054309715969
# 3  1040330596545904643  818554054309715969
# 4   923648345394040833  818554054309715969
#
#                                                 Text            Timestamp
# 0  The skyrocketing cost of life-saving medicatio...  2018-05-16 19:41:06
# 1  To all of the brave women who have had to say ...  2017-06-23 21:04:19
# 2  #Passover is a beautiful time to remember our ...  2018-03-31 04:17:40
# 3  I was glad to help pass bipartisan legislation...  2018-09-13 20:05:17
# 4  GOP budget does nothing to help Nevada's middl...  2017-10-26 20:31:40

# %%
final_legis_info_and_tbip_data = pd.read_csv('../../legislator_info_and_tbip_congresses_115_and_116.csv')
# NOTE: while above file is ultimately created using the ideal point estimates... we only create these other files
# as resulting files for legislators ultimately retained in the final file containing everything used for research.


included_bid_to_tbip = dict(zip(final_legis_info_and_tbip_data.Bioguide_ID, 
                       final_legis_info_and_tbip_data.TBIP_Tweets))
relev_bids = []
for bid in included_bid_to_tbip:
    if np.isnan(included_bid_to_tbip[bid]):
        continue
    relev_bids.append(bid)
print(len(relev_bids))
# Out:
# 471

# %%
tweets_data.Timestamp = pd.to_datetime(tweets_data.Timestamp)
print(tweets_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295327 entries, 0 to 295326
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Tweet ID   295327 non-null  int64
#  1   Author ID  295327 non-null  int64
#  2   Text       295327 non-null  object
#  3   Timestamp  295327 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 9.0+ MB
# None

# %%
speaker_ids_from_data = list(tweets_data['Author ID'])
speaker_ids_from_data = list(map(lambda x:twitter_uid_to_bid[x], speaker_ids_from_data))
texts_from_data = list(tweets_data['Text'])
dates_from_data = list(tweets_data['Timestamp'])

# %%
retain_inds = []
all_relev_ids, all_relev_texts, all_relev_dates = [], [], []
for i, bid in enumerate(speaker_ids_from_data):
    if bid in relev_bids:
        retain_inds.append(i)
        all_relev_ids.append(bid)
        all_relev_texts.append(texts_from_data[i])
        all_relev_dates.append(dates_from_data[i])
print(len(retain_inds))
# Out:
# 295327

# %%
document_mean = document_mean[retain_inds]
document_mean = np.array(torch.softmax(torch.from_numpy(document_mean), 1))
print(document_mean.shape)
# Out:
# (295327, 50)

# %%
texts_topics = pd.DataFrame()
texts_topics["Bioguide_ID"] = all_relev_ids
texts_topics["Text"] = all_relev_texts
texts_topics["Timestamp"] = all_relev_dates

# %%
for topic_ind in range(document_mean.shape[1]):
    texts_topics['Topic' + str(topic_ind)] = list(map(lambda x:np.float32(str(x)), list(document_mean[:, topic_ind])))

# %%
print(texts_topics.info())
texts_topics
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295327 entries, 0 to 295326
# Data columns (total 53 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Bioguide_ID  295327 non-null  object
#  1   Text         295327 non-null  object
#  2   Timestamp    295327 non-null  datetime64[ns]
#  3   Topic0       295327 non-null  float64
#  4   Topic1       295327 non-null  float64
#  5   Topic2       295327 non-null  float64
#  6   Topic3       295327 non-null  float64
#  7   Topic4       295327 non-null  float64
#  8   Topic5       295327 non-null  float64
#  9   Topic6       295327 non-null  float64
#  10  Topic7       295327 non-null  float64
#  11  Topic8       295327 non-null  float64
#  12  Topic9       295327 non-null  float64
#  13  Topic10      295327 non-null  float64
#  14  Topic11      295327 non-null  float64
#  15  Topic12      295327 non-null  float64
#  16  Topic13      295327 non-null  float64
#  17  Topic14      295327 non-null  float64
#  18  Topic15      295327 non-null  float64
#  19  Topic16      295327 non-null  float64
#  20  Topic17      295327 non-null  float64
#  21  Topic18      295327 non-null  float64
#  22  Topic19      295327 non-null  float64
#  23  Topic20      295327 non-null  float64
#  24  Topic21      295327 non-null  float64
#  25  Topic22      295327 non-null  float64
#  26  Topic23      295327 non-null  float64
#  27  Topic24      295327 non-null  float64
#  28  Topic25      295327 non-null  float64
#  29  Topic26      295327 non-null  float64
#  30  Topic27      295327 non-null  float64
#  31  Topic28      295327 non-null  float64
#  32  Topic29      295327 non-null  float64
#  33  Topic30      295327 non-null  float64
#  34  Topic31      295327 non-null  float64
#  35  Topic32      295327 non-null  float64
#  36  Topic33      295327 non-null  float64
#  37  Topic34      295327 non-null  float64
#  38  Topic35      295327 non-null  float64
#  39  Topic36      295327 non-null  float64
#  40  Topic37      295327 non-null  float64
#  41  Topic38      295327 non-null  float64
#  42  Topic39      295327 non-null  float64
#  43  Topic40      295327 non-null  float64
#  44  Topic41      295327 non-null  float64
#  45  Topic42      295327 non-null  float64
#  46  Topic43      295327 non-null  float64
#  47  Topic44      295327 non-null  float64
#  48  Topic45      295327 non-null  float64
#  49  Topic46      295327 non-null  float64
#  50  Topic47      295327 non-null  float64
#  51  Topic48      295327 non-null  float64
#  52  Topic49      295327 non-null  float64
# dtypes: datetime64[ns](1), float64(50), object(2)
# memory usage: 119.4+ MB
# None
#        Bioguide_ID                                               Text  \
# 0          R000608  The skyrocketing cost of life-saving medicatio...
# 1          R000608  To all of the brave women who have had to say ...
# 2          R000608  #Passover is a beautiful time to remember our ...
# 3          R000608  I was glad to help pass bipartisan legislation...
# 4          R000608  GOP budget does nothing to help Nevada's middl...
# ...            ...                                                ...
# 295322     B001311  RT @RepMattGaetz: "If you accept all of their ...
# 295323     B001311         Merry Christmas! 🎄 https://t.co/QsShG6aykE
# 295324     B001311  Been working hard w/ @Statedept to help get US...
# 295325     B001311  👏 @Allstate is REFUNDING $$$ hundreds of milli...
# 295326     B001311  This President, @realDonaldTrump stands for LI...
#
#                  Timestamp        Topic0        Topic1        Topic2  \
# 0      2018-05-16 19:41:06  4.963950e-10  3.773803e-10  5.296226e-10
# 1      2017-06-23 21:04:19  2.729059e-02  8.922050e-03  8.401409e-03
# 2      2018-03-31 04:17:40  8.554869e-06  2.751229e-06  3.428339e-06
# 3      2018-09-13 20:05:17  5.748105e-08  2.425721e-08  3.063078e-08
# 4      2017-10-26 20:31:40  4.652912e-07  4.193509e-07  7.384368e-07
# ...                    ...           ...           ...           ...
# 295322 2019-12-04 18:45:07  1.279216e-02  1.771166e-02  2.196138e-02
# 295323 2019-12-25 18:23:45  1.702594e-03  3.533124e-03  2.896988e-03
# 295324 2020-03-27 19:47:47  9.076281e-03  1.005910e-02  9.407829e-03
# 295325 2020-04-07 20:08:57  1.954941e-07  4.706637e-07  2.085140e-07
# 295326 2020-02-05 03:03:52  5.615778e-03  6.592018e-03  4.815049e-03
#
#               Topic3        Topic4        Topic5        Topic6  ...  \
# 0       5.210248e-10  6.010184e-10  3.932444e-10  1.102688e-09  ...
# 1       1.085479e-02  9.115369e-03  9.636827e-03  9.053043e-03  ...
# 2       2.412011e-06  9.962156e-01  3.167376e-06  2.588517e-06  ...
# 3       2.513337e-08  1.931524e-08  3.416139e-07  3.907677e-08  ...
# 4       4.020405e-07  4.980043e-07  7.877406e-07  4.075310e-07  ...
# ...              ...           ...           ...           ...  ...
# 295322  2.256744e-02  1.292124e-02  1.239425e-02  2.180657e-02  ...
# 295323  1.981668e-03  8.997316e-01  1.514078e-03  1.373954e-03  ...
# 295324  8.749188e-03  1.232147e-01  2.913292e-02  2.191692e-01  ...
# 295325  2.767639e-07  3.550961e-07  3.451636e-07  4.695545e-07  ...
# 295326  2.250117e-02  4.140845e-03  6.214526e-03  6.624064e-03  ...
#
#              Topic40       Topic41       Topic42       Topic43       Topic44  \
# 0       6.037760e-10  4.906782e-10  9.130554e-10  3.175643e-10  3.456588e-07
# 1       7.630489e-03  1.434223e-02  1.058010e-02  1.330151e-02  9.308327e-03
# 2       2.689379e-06  2.811784e-06  2.209202e-06  2.464343e-06  2.612589e-06
# 3       3.169257e-08  2.638630e-08  5.060026e-08  2.274637e-08  2.190512e-08
# 4       4.046053e-07  4.380161e-07  4.553031e-07  3.635515e-07  6.520915e-07
# ...              ...           ...           ...           ...           ...
# 295322  1.794208e-02  1.612906e-02  1.843484e-02  1.375183e-02  2.208498e-02
# 295323  1.402275e-03  2.444467e-03  2.141321e-03  2.220500e-03  1.573489e-03
# 295324  1.266893e-02  8.269025e-03  8.378092e-03  7.247412e-03  1.083687e-02
# 295325  4.859219e-07  1.910311e-07  3.031047e-07  6.710041e-05  4.531999e-07
# 295326  5.426563e-03  7.107185e-03  4.952604e-03  6.098821e-03  5.199463e-03
#
#              Topic45       Topic46       Topic47       Topic48       Topic49
# 0       5.551402e-10  4.296170e-10  9.850813e-10  3.213561e-10  4.410904e-10
# 1       7.347345e-03  3.608839e-02  1.301936e-02  6.946318e-03  1.020903e-02
# 2       4.027968e-06  1.879338e-06  2.431450e-06  2.529632e-06  2.432784e-06
# 3       1.452587e-07  2.440651e-08  4.107147e-08  3.119926e-08  2.735903e-08
# 4       3.766006e-01  6.594825e-07  4.825466e-07  6.208430e-07  4.546258e-07
# ...              ...           ...           ...           ...           ...
# 295322  1.362797e-02  1.436380e-02  2.104737e-02  1.914472e-02  1.093400e-02
# 295323  1.365747e-03  1.348756e-03  1.862440e-03  2.171565e-03  1.311586e-03
# 295324  1.176402e-02  1.019323e-02  1.048611e-02  1.633170e-02  1.062113e-02
# 295325  5.317777e-07  2.642632e-07  3.339371e-07  3.660530e-07  5.856515e-07
# 295326  6.605644e-03  4.722017e-03  4.460874e-03  9.556294e-03  1.262402e-02
#
# [295327 rows x 53 columns]

# %%
texts_topics.to_csv('../../tweets_results/texts_topic_proportions.csv',
                    index=False)

# %%
relev_bid_to_inds = {}
for bid in relev_bids:
    relev_bid_to_inds[bid] = []
for i, idd in enumerate(all_relev_ids):
        relev_bid_to_inds[idd].append(i)

# %%
def get_mean_topic_props_author(X, bid, author_to_inds):
    return np.mean(X[author_to_inds[bid]], 0).reshape((1, num_topics))

# %%
relev_bid_avg_topic_props = []
for bid in relev_bids:
    relev_bid_avg_topic_props.append(get_mean_topic_props_author(document_mean, 
                                                                 bid,
                                                                 relev_bid_to_inds))
relev_bid_avg_topic_props = np.concatenate(relev_bid_avg_topic_props, 0)
print(relev_bid_avg_topic_props.shape)
# Out:
# (471, 50)

# %%
author_topic_props = pd.DataFrame()
author_topic_props["Bioguide_ID"] = relev_bids

# %%
for topic_ind in range(num_topics):
    author_topic_props['Topic' + str(topic_ind)] = list(relev_bid_avg_topic_props[:, topic_ind])

# %%
print(author_topic_props.info())
author_topic_props
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471 entries, 0 to 470
# Data columns (total 51 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Bioguide_ID  471 non-null    object
#  1   Topic0       471 non-null    float64
#  2   Topic1       471 non-null    float64
#  3   Topic2       471 non-null    float64
#  4   Topic3       471 non-null    float64
#  5   Topic4       471 non-null    float64
#  6   Topic5       471 non-null    float64
#  7   Topic6       471 non-null    float64
#  8   Topic7       471 non-null    float64
#  9   Topic8       471 non-null    float64
#  10  Topic9       471 non-null    float64
#  11  Topic10      471 non-null    float64
#  12  Topic11      471 non-null    float64
#  13  Topic12      471 non-null    float64
#  14  Topic13      471 non-null    float64
#  15  Topic14      471 non-null    float64
#  16  Topic15      471 non-null    float64
#  17  Topic16      471 non-null    float64
#  18  Topic17      471 non-null    float64
#  19  Topic18      471 non-null    float64
#  20  Topic19      471 non-null    float64
#  21  Topic20      471 non-null    float64
#  22  Topic21      471 non-null    float64
#  23  Topic22      471 non-null    float64
#  24  Topic23      471 non-null    float64
#  25  Topic24      471 non-null    float64
#  26  Topic25      471 non-null    float64
#  27  Topic26      471 non-null    float64
#  28  Topic27      471 non-null    float64
#  29  Topic28      471 non-null    float64
#  30  Topic29      471 non-null    float64
#  31  Topic30      471 non-null    float64
#  32  Topic31      471 non-null    float64
#  33  Topic32      471 non-null    float64
#  34  Topic33      471 non-null    float64
#  35  Topic34      471 non-null    float64
#  36  Topic35      471 non-null    float64
#  37  Topic36      471 non-null    float64
#  38  Topic37      471 non-null    float64
#  39  Topic38      471 non-null    float64
#  40  Topic39      471 non-null    float64
#  41  Topic40      471 non-null    float64
#  42  Topic41      471 non-null    float64
#  43  Topic42      471 non-null    float64
#  44  Topic43      471 non-null    float64
#  45  Topic44      471 non-null    float64
#  46  Topic45      471 non-null    float64
#  47  Topic46      471 non-null    float64
#  48  Topic47      471 non-null    float64
#  49  Topic48      471 non-null    float64
#  50  Topic49      471 non-null    float64
# dtypes: float64(50), object(1)
# memory usage: 187.8+ KB
# None
#     Bioguide_ID    Topic0    Topic1    Topic2    Topic3    Topic4    Topic5  \
# 0       A000055  0.022957  0.034588  0.018237  0.017258  0.014678  0.020173
# 1       A000367  0.014456  0.016591  0.017763  0.017173  0.027282  0.019257
# 2       A000370  0.019121  0.016536  0.017995  0.010555  0.015216  0.019707
# 3       A000371  0.016413  0.021756  0.026164  0.009264  0.025473  0.014424
# 4       A000372  0.009323  0.030266  0.037240  0.021548  0.034366  0.043011
# ..          ...       ...       ...       ...       ...       ...       ...
# 466     Y000033  0.030443  0.027125  0.018845  0.019399  0.028535  0.023730
# 467     Y000062  0.011217  0.023819  0.025872  0.043340  0.026072  0.012256
# 468     Y000065  0.014928  0.019125  0.006034  0.021565  0.023981  0.019317
# 469     Y000066  0.013007  0.019855  0.031433  0.034459  0.024164  0.011088
# 470     Z000017  0.013870  0.014289  0.011786  0.023818  0.023259  0.019377
#
#        Topic6    Topic7    Topic8  ...   Topic40   Topic41   Topic42  \
# 0    0.010822  0.034457  0.013750  ...  0.021959  0.016912  0.010786
# 1    0.010935  0.009101  0.010002  ...  0.026245  0.018628  0.013234
# 2    0.022182  0.101135  0.029285  ...  0.014269  0.014094  0.020195
# 3    0.033159  0.016009  0.059210  ...  0.019139  0.010741  0.005105
# 4    0.018999  0.040080  0.040374  ...  0.016162  0.018643  0.013643
# ..        ...       ...       ...  ...       ...       ...       ...
# 466  0.008535  0.012005  0.011057  ...  0.024970  0.014881  0.012594
# 467  0.020057  0.014939  0.012956  ...  0.015985  0.006912  0.011419
# 468  0.011259  0.032313  0.016154  ...  0.020324  0.011322  0.008861
# 469  0.009982  0.030010  0.042604  ...  0.017244  0.012494  0.013399
# 470  0.009909  0.011710  0.013063  ...  0.022357  0.029303  0.007796
#
#       Topic43   Topic44   Topic45   Topic46   Topic47   Topic48   Topic49
# 0    0.021198  0.009488  0.011509  0.006141  0.007452  0.012618  0.030016
# 1    0.012326  0.009139  0.013505  0.011133  0.011980  0.012391  0.011835
# 2    0.016259  0.022285  0.019404  0.025066  0.007491  0.012865  0.014002
# 3    0.024956  0.013815  0.015092  0.012697  0.004854  0.013239  0.009068
# 4    0.023351  0.016187  0.007704  0.010989  0.027051  0.016290  0.013758
# ..        ...       ...       ...       ...       ...       ...       ...
# 466  0.013978  0.017863  0.011236  0.009194  0.011527  0.013420  0.020649
# 467  0.009806  0.021181  0.051542  0.025068  0.012607  0.017957  0.017291
# 468  0.024236  0.017501  0.006270  0.008622  0.011532  0.013311  0.015742
# 469  0.016834  0.012615  0.009568  0.006890  0.021387  0.011763  0.014933
# 470  0.012785  0.011370  0.010251  0.012769  0.014252  0.011457  0.023650
#
# [471 rows x 51 columns]

# %%
author_topic_props.to_csv('../../tweets_results/topic_proportions_per_author.csv',
                          index=False)
